# %%
import draco as drc
import pandas as pd
from vega_datasets import data as vega_data
import altair as alt
from IPython.display import display, Markdown
import json
import numpy as np
from draco.renderer import AltairRenderer
# alt.renderers.enable("png")
import pdb
from draco import Draco
dr_check=Draco()
from itertools import permutations


# Handles serialization of common numpy datatypes
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)


def md(markdown: str):
    display(Markdown(markdown))


def pprint(obj):
    md(f"```json\n{json.dumps(obj, indent=2, cls=NpEncoder)}\n```")

def localpprint(obj):
        print(json.dumps(obj, indent=2, cls=NpEncoder))

def recommend_charts(
    spec: list[str], draco: drc.Draco, df: pd.DataFrame, num: int = 5, labeler=lambda i: f"CHART {i+1}"
) -> dict[str, tuple[list[str], dict]]:
    # Dictionary to store the generated recommendations, keyed by chart name

    renderer = AltairRenderer()
    chart_specs = {}
    chart_vega_specs = {}
    for i, model in enumerate(draco.complete_spec(spec, num)):
        chart_name = labeler(i)
        spec = drc.answer_set_to_dict(model.answer_set)
        chart_specs[chart_name] = drc.dict_to_facts(spec), spec
        chart = renderer.render(spec=spec, data=df)
        if not ( isinstance(chart, alt.FacetChart) or isinstance(chart, alt.LayerChart)):
            chart_vega_specs[chart_name] = {'chart': chart.to_json(), 'cost': model.cost[0]}

    return chart_vega_specs

# %%
def rec_from_generated_spec(
    marks: list[str],
    fields: list[str],
    encoding_channels: list[str],
    draco: drc.Draco,
    input_spec_base: list[str],
    data: pd.DataFrame,
    num: int = 5, config=None
) -> dict[str, dict]:
    if config is None:
        # make different arrangement of fields elements
        perms_fields = list(permutations(fields))
        input_specs = []
        for fields in perms_fields:
          # for mark in marks:
            force_attributes = []

            for index, item in enumerate(fields):
                connect_root = f'entity(encoding,m0,e{index}).'
                force_attributes.append(connect_root)
                specify_field = f'attribute((encoding,field),e{index},{item}).'
                force_attributes.append(specify_field)
            spec =(
                    (str(fields) ,'any-mark'),
                    input_spec_base
                    # +
                    # [
                    #     f"attribute((mark,type),m0,{mark})."
                    # ]
                    +

                    force_attributes
                    +

                    [
                        # ":- {attribute((encoding,field),_,_)} =" + str(num_encodings) + ".",
                        ":- {attribute((encoding,field),_,_)} < 1."
                    ]
                )
            input_specs.append(spec)


        recs = {}
        for cfg, spec in input_specs:
            labeler = lambda i: f"CHART {i + 1} ({' | '.join(cfg)})"
            try:
                new_recs = recommend_charts(spec=spec, draco=draco, df=data, num=num, labeler=labeler)
                recs.update(new_recs)
            except:
                print('Altair went wrong')
                pass

    # sort recs by cost
    recs = dict(sorted(recs.items(), key=lambda item: item[1]['cost']))
    # remove the cost from the dictionary
    new_recs = {}
    for key in recs:
        cost=recs[key]['cost']
        new_key = key + str(cost)
        new_recs[new_key] = recs[key]['chart']

    return new_recs

# %%
def start_draco(fields,datasetname='birdstrikes',config=None):
    # Loading data to be explored
    d = drc.Draco()
    if datasetname == 'movies':
        df: pd.DataFrame = vega_data.movies()
        # df = df.drop(columns = 'Worldwide_Gross')
    elif datasetname=='seattle':
        df: pd.DataFrame = vega_data.seattle_weather()
    else:
        df: pd.DataFrame = vega_data.birdstrikes()
        df = df.sample(n=500, random_state=1)
    # print(df.head(10))
    df.columns = [col.replace('__', '_').lower() for col in df.columns]
    df.columns = [col.replace('$', 'a') for col in df.columns]
    data_schema = drc.schema_from_dataframe(df)
    # pprint(data_schema)
    data_schema_facts = drc.dict_to_facts(data_schema)
    # print(df.columns)
    # pprint(data_schema_facts)

    input_spec_base = data_schema_facts + [
        "entity(view,root,v0).",
        "entity(mark,v0,m0).",
    ]
    # initial_recommendations = recommend_charts(spec=input_spec_base, draco=d, df=df)

    recommendations = rec_from_generated_spec(
    marks=['bar', 'point', 'circle', 'line', 'tick'],
    fields=fields,
    encoding_channels=["x", "y", "color", "shape", "size"],
    draco=d,
    input_spec_base=input_spec_base,
    data=df,
    config=config
    )
    return recommendations

# %%
def get_draco_recommendations(attributes,datasetname='birdstrikes',config=None):
    ret = [f.replace('__', '_').lower() for f in attributes]
    field_names_renamed = [f.replace('$', 'a') for f in ret]
    recommendations=start_draco(fields=field_names_renamed,datasetname=datasetname,config=config)
    return recommendations


if __name__ == '__main__':
    fields_birdstrikes = ['cost_other','wildlife_size']
    recommendations=get_draco_recommendations(fields_birdstrikes, datasetname='birdstrikes')
    for chart_key, _ in recommendations.items():
        chart = recommendations[chart_key]
        print(f"Recommendation for {chart_key}:")
        #get the mark type
        mark = json.loads(chart)['mark']
        encoding = json.loads(chart)['encoding']
        print(mark)
        print(encoding)
# Out:
# Recommendation for CHART 1 (('cost_other', 'wildlife_size') | any-mark)14:
# {'type': 'tick'}
# {'x': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}, 'y': {'field': 'wildlife_size', 'type': 'ordinal'}}
# Recommendation for CHART 2 (('cost_other', 'wildlife_size') | any-mark)14:
# {'type': 'tick'}
# {'x': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}, 'y': {'field': 'wildlife_size', 'type': 'ordinal'}}
# Recommendation for CHART 1 (('wildlife_size', 'cost_other') | any-mark)14:
# {'type': 'tick'}
# {'x': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}, 'y': {'field': 'wildlife_size', 'type': 'ordinal'}}
# Recommendation for CHART 2 (('wildlife_size', 'cost_other') | any-mark)14:
# {'type': 'tick'}
# {'x': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}, 'y': {'field': 'wildlife_size', 'type': 'ordinal'}}
# Recommendation for CHART 3 (('cost_other', 'wildlife_size') | any-mark)15:
# {'type': 'tick'}
# {'x': {'field': 'wildlife_size', 'type': 'ordinal'}, 'y': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}}
# Recommendation for CHART 4 (('cost_other', 'wildlife_size') | any-mark)15:
# {'type': 'tick'}
# {'x': {'field': 'wildlife_size', 'type': 'ordinal'}, 'y': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}}
# Recommendation for CHART 3 (('wildlife_size', 'cost_other') | any-mark)15:
# {'type': 'tick'}
# {'x': {'field': 'wildlife_size', 'type': 'ordinal'}, 'y': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}}
# Recommendation for CHART 4 (('wildlife_size', 'cost_other') | any-mark)15:
# {'type': 'tick'}
# {'x': {'field': 'wildlife_size', 'type': 'ordinal'}, 'y': {'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}}
# Recommendation for CHART 5 (('cost_other', 'wildlife_size') | any-mark)16:
# {'type': 'bar'}
# {'x': {'aggregate': 'mean', 'field': 'cost_other', 'scale': {'type': 'linear', 'zero': True}, 'type': 'quantitative'}, 'y': {'field': 'wildlife_size', 'type': 'ordinal'}}

# %% [markdown]
# # ## Draco Recommendations Findings
# 1) The order how the attributes are passed does not matter
# 2) Looking at the costs it makes sense for point to be popular since Draco says its lowest cost

# %%
import numpy as np

# List of variables to load
variables = [
    'response_history', 'state_history', 'momentum_attributes_history',
    'greedy_attributes_history', 'random_attributes_history',
    'rl_attributes_history', 'last_users_attributes_history',
    'actor_critic_action_history', 'rl_accuracies', 'random_accuracies',
    'momentum_accuracies', 'greedy_accuracies', 'master_current_user_attributes',
    'current_user_attributes', 'interaction_map', 'dataset', 'fieldnames',
    'all_algorithms_distribution_map', 'user_distribution_map',
    'response_algorithm_predictions', 'response_accuracy'
]

# Load the model
model_path = '/Users/aryal/Desktop/Personal/RLVisRec/interface/ShiftScopeLogs/20240523193204/online_learning_models.pkl'
model = np.load(model_path, allow_pickle=True)

# Create a dictionary to store the loaded variables
loaded_model = {}

# Access each variable from the model and store it in the dictionary
for key in variables:
    if hasattr(model, key):
        loaded_model[key] = getattr(model, key)
    else:
        print(f"Warning: The model does not have attribute '{key}'")

# Now, loaded_model contains the desired attributes from the model

# %%
loaded_model
# Out:
# {'response_history': [['cost_total_a', 'airport_name', 'none'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['cost_other', 'when_time_of_day', 'aircraft_make_model'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['cost_total_a', 'airport_name', 'none'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['cost_other', 'when_time_of_day', 'aircraft_make_model'],
#   ['cost_repair', 'wildlife_species', 'origin_state'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['cost_repair', 'when_phase_of_flight', 'when_time_of_day'],
#   ['cost_repair', 'wildlife_species', 'origin_state'],
#   ['when_time_of_day', 'airport_name', 'wildlife_species'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['when_time_of_day', 'airport_name', 'wildlife_species'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage'],
#   ['wildlife_size', 'origin_state', 'aircraft_make_model'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage']],
#  'state_history': [['cost_total_a', 'airport_name', 'none'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['cost_total_a', 'airport_name', 'none'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['wildlife_species', 'origin_state', 'cost_repair'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['when_phase_of_flight', 'when_time_of_day', 'cost_repair'],
#   ['wildlife_species', 'origin_state', 'cost_repair'],
#   ['wildlife_species', 'origin_state', 'cost_repair'],
#   ['when_time_of_day', 'airport_name', 'wildlife_species'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['when_time_of_day', 'airport_name', 'wildlife_species'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage'],
#   ['wildlife_size', 'origin_state', 'aircraft_make_model'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage']],
#  'momentum_attributes_history': [['flight_date',
#    'wildlife_size',
#    'airport_name'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['wildlife_species', 'origin_state', 'cost_repair']],
#  'greedy_attributes_history': [['flight_date',
#    'wildlife_size',
#    'airport_name'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['wildlife_species', 'origin_state', 'cost_repair']],
#  'random_attributes_history': [['effect_amount_of_damage',
#    'aircraft_airline_operator',
#    'origin_state'],
#   ['airport_name', 'when_phase_of_flight', 'none'],
#   ['aircraft_make_model', 'flight_date', 'origin_state'],
#   ['wildlife_species', 'when_time_of_day', 'cost_total_a']],
#  'rl_attributes_history': [[['airport_name', 'cost_total_a', 'none'],
#    ['aircraft_make_model', 'none', 'origin_state'],
#    ['aircraft_make_model', 'cost_other', 'when_time_of_day'],
#    ['cost_other', 'cost_total_a', 'wildlife_size'],
#    ['speed_ias_in_knots', 'when_time_of_day', 'wildlife_species'],
#    ['cost_repair', 'cost_total_a', 'effect_amount_of_damage']],
#   [['cost_other', 'none', 'wildlife_size'],
#    ['aircraft_make_model', 'effect_amount_of_damage', 'flight_date'],
#    ['flight_date', 'speed_ias_in_knots', 'wildlife_species'],
#    ['cost_total_a', 'none', 'wildlife_size'],
#    ['cost_repair', 'origin_state', 'wildlife_species'],
#    ['airport_name', 'cost_total_a', 'none']],
#   [['cost_repair', 'when_phase_of_flight', 'when_time_of_day'],
#    ['cost_repair', 'origin_state', 'wildlife_species'],
#    ['cost_total_a', 'none', 'wildlife_size'],
#    ['cost_repair', 'wildlife_species', 'none'],
#    ['cost_other', 'cost_repair', 'speed_ias_in_knots'],
#    ['airport_name', 'cost_repair', 'cost_total_a']],
#   [['aircraft_make_model', 'origin_state', 'wildlife_size'],
#    ['aircraft_make_model', 'cost_other', 'cost_repair'],
#    ['cost_other', 'effect_amount_of_damage', 'wildlife_species'],
#    ['cost_repair', 'cost_total_a', 'effect_amount_of_damage'],
#    ['airport_name', 'when_time_of_day', 'wildlife_species'],
#    ['aircraft_make_model', 'wildlife_species', 'none']]],
#  'last_users_attributes_history': [['cost_total_a', 'airport_name', 'none'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['cost_total_a', 'airport_name', 'none'],
#   ['origin_state', 'aircraft_make_model', 'none'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['when_time_of_day', 'aircraft_make_model', 'cost_other'],
#   ['wildlife_species', 'origin_state', 'cost_repair'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['cost_total_a', 'wildlife_size', 'none'],
#   ['when_phase_of_flight', 'when_time_of_day', 'cost_repair'],
#   ['wildlife_species', 'origin_state', 'cost_repair'],
#   ['wildlife_species', 'origin_state', 'cost_repair'],
#   ['when_time_of_day', 'airport_name', 'wildlife_species'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['when_time_of_day', 'airport_name', 'wildlife_species'],
#   ['cost_repair', 'effect_amount_of_damage', 'cost_total_a'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage'],
#   ['wildlife_size', 'origin_state', 'aircraft_make_model'],
#   ['cost_other', 'wildlife_species', 'effect_amount_of_damage']],
#  'actor_critic_action_history': [[['airport_name', 'cost_total_a', 'none'],
#    ['aircraft_make_model', 'none', 'origin_state'],
#    ['aircraft_make_model', 'cost_other', 'when_time_of_day'],
#    ['cost_other', 'cost_total_a', 'wildlife_size'],
#    ['speed_ias_in_knots', 'when_time_of_day', 'wildlife_species'],
#    ['cost_repair', 'cost_total_a', 'effect_amount_of_damage']],
#   [['cost_other', 'none', 'wildlife_size'],
#    ['aircraft_make_model', 'effect_amount_of_damage', 'flight_date'],
#    ['flight_date', 'speed_ias_in_knots', 'wildlife_species'],
#    ['cost_total_a', 'none', 'wildlife_size'],
#    ['cost_repair', 'origin_state', 'wildlife_species'],
#    ['airport_name', 'cost_total_a', 'none']],
#   [['cost_repair', 'when_phase_of_flight', 'when_time_of_day'],
#    ['cost_repair', 'origin_state', 'wildlife_species'],
#    ['cost_total_a', 'none', 'wildlife_size'],
#    ['cost_repair', 'wildlife_species', 'none'],
#    ['cost_other', 'cost_repair', 'speed_ias_in_knots'],
#    ['airport_name', 'cost_repair', 'cost_total_a']],
#   [['aircraft_make_model', 'origin_state', 'wildlife_size'],
#    ['aircraft_make_model', 'cost_other', 'cost_repair'],
#    ['cost_other', 'effect_amount_of_damage', 'wildlife_species'],
#    ['cost_repair', 'cost_total_a', 'effect_amount_of_damage'],
#    ['airport_name', 'when_time_of_day', 'wildlife_species'],
#    ['aircraft_make_model', 'wildlife_species', 'none']]],
#  'rl_accuracies': [0.3333333333333333, 0.3333333333333333],
#  'random_accuracies': [0.3333333333333333, 0.16666666666666666],
#  'momentum_accuracies': [0.0, 0.5],
#  'greedy_accuracies': [],
#  'master_current_user_attributes': None,
#  'current_user_attributes': [['cost_total_a', 'wildlife_size', 'none'],
#   ['wildlife_species', 'origin_state', 'cost_repair']],
#  'interaction_map': {0: [], 1: [10], 2: [13]},
#  'dataset': 'birdstrikes',
#  'fieldnames': ['airport_name',
#   'aircraft_make_model',
#   'effect_amount_of_damage',
#   'flight_date',
#   'aircraft_airline_operator',
#   'origin_state',
#   'when_phase_of_flight',
#   'wildlife_size',
#   'wildlife_species',
#   'when_time_of_day',
#   'cost_other',
#   'cost_repair',
#   'cost_total_a',
#   'speed_ias_in_knots'],
#  'all_algorithms_distribution_map': {'Momentum': {'airport_name': 0.0909090909090909,
#    'aircraft_make_model': 0.0909090909090909,
#    'effect_amount_of_damage': 0.0,
#    'flight_date': 0.0909090909090909,
#    'aircraft_airline_operator': 0.0,
#    'origin_state': 0.0909090909090909,
#    'when_phase_of_flight': 0.0,
#    'wildlife_size': 0.1818181818181818,
#    'wildlife_species': 0.0909090909090909,
#    'when_time_of_day': 0.0909090909090909,
#    'cost_other': 0.0909090909090909,
#    'cost_repair': 0.0909090909090909,
#    'cost_total_a': 0.0909090909090909,
#    'speed_ias_in_knots': 0.0},
#   'Greedy': {'airport_name': 0.0625,
#    'aircraft_make_model': 0.09375,
#    'effect_amount_of_damage': 0.0625,
#    'flight_date': 0.03125,
#    'aircraft_airline_operator': 0.0,
#    'origin_state': 0.0625,
#    'when_phase_of_flight': 0.015625,
#    'wildlife_size': 0.078125,
#    'wildlife_species': 0.125,
#    'when_time_of_day': 0.0625,
#    'cost_other': 0.09375,
#    'cost_repair': 0.140625,
#    'cost_total_a': 0.125,
#    'speed_ias_in_knots': 0.046875},
#   'Random': {'airport_name': 0.0909090909090909,
#    'aircraft_make_model': 0.0909090909090909,
#    'effect_amount_of_damage': 0.0909090909090909,
#    'flight_date': 0.0909090909090909,
#    'aircraft_airline_operator': 0.0909090909090909,
#    'origin_state': 0.1818181818181818,
#    'when_phase_of_flight': 0.0909090909090909,
#    'wildlife_size': 0.0,
#    'wildlife_species': 0.0909090909090909,
#    'when_time_of_day': 0.0909090909090909,
#    'cost_other': 0.0,
#    'cost_repair': 0.0,
#    'cost_total_a': 0.0909090909090909,
#    'speed_ias_in_knots': 0.0},
#   'Actor_Critic': {'airport_name': 0.0625,
#    'aircraft_make_model': 0.09375,
#    'effect_amount_of_damage': 0.0625,
#    'flight_date': 0.03125,
#    'aircraft_airline_operator': 0.0,
#    'origin_state': 0.0625,
#    'when_phase_of_flight': 0.015625,
#    'wildlife_size': 0.078125,
#    'wildlife_species': 0.125,
#    'when_time_of_day': 0.0625,
#    'cost_other': 0.09375,
#    'cost_repair': 0.140625,
#    'cost_total_a': 0.125,
#    'speed_ias_in_knots': 0.046875}},
#  'user_distribution_map': {'airport_name': 0.05714285714285714,
#   'aircraft_make_model': 0.17142857142857143,
#   'effect_amount_of_damage': 0.0,
#   'flight_date': 0.0,
#   'aircraft_airline_operator': 0.0,
#   'origin_state': 0.17142857142857143,
#   'when_phase_of_flight': 0.02857142857142857,
#   'wildlife_size': 0.05714285714285714,
#   'wildlife_species': 0.08571428571428572,
#   'when_time_of_day': 0.11428571428571428,
#   'cost_other': 0.08571428571428572,
#   'cost_repair': 0.11428571428571428,
#   'cost_total_a': 0.11428571428571428,
#   'speed_ias_in_knots': 0.0},
#  'response_algorithm_predictions': {'RL': [[['aircraft_make_model',
#      'cost_other',
#      'when_time_of_day'],
#     ['aircraft_make_model', 'none', 'origin_state'],
#     ['airport_name', 'cost_total_a', 'none'],
#     ['cost_other', 'cost_total_a', 'wildlife_size'],
#     ['cost_repair', 'cost_total_a', 'effect_amount_of_damage'],
#     ['speed_ias_in_knots', 'when_time_of_day', 'wildlife_species']],
#    [['aircraft_make_model', 'effect_amount_of_damage', 'flight_date'],
#     ['airport_name', 'cost_total_a', 'none'],
#     ['cost_other', 'none', 'wildlife_size'],
#     ['cost_repair', 'origin_state', 'wildlife_species'],
#     ['cost_total_a', 'none', 'wildlife_size'],
#     ['flight_date', 'speed_ias_in_knots', 'wildlife_species']],
#    [['airport_name', 'cost_repair', 'cost_total_a'],
#     ['cost_other', 'cost_repair', 'speed_ias_in_knots'],
#     ['cost_repair', 'origin_state', 'wildlife_species'],
#     ['cost_repair', 'when_phase_of_flight', 'when_time_of_day'],
#     ['cost_repair', 'wildlife_species', 'none'],
#     ['cost_total_a', 'none', 'wildlife_size']]],
#   'Random': [['aircraft_airline_operator',
#     'effect_amount_of_damage',
#     'origin_state'],
#    ['airport_name', 'none', 'when_phase_of_flight'],
#    ['aircraft_make_model', 'flight_date', 'origin_state']],
#   'Momentum': [['airport_name', 'flight_date', 'wildlife_size'],
#    ['aircraft_make_model', 'cost_other', 'when_time_of_day'],
#    ['cost_total_a', 'none', 'wildlife_size']]},
#  'response_accuracy': {'RL': [0.3333333333333333, 0.3333333333333333],
#   'Random': [0.3333333333333333, 0.16666666666666666],
#   'Momentum': [0.0, 0.5]}}
